# %%
# !git clone https://github.com/microsoft/onnxruntime.git
# Out:
# Cloning into 'onnxruntime'...
# remote: Enumerating objects: 352402, done.
# remote: Counting objects: 100% (211/211), done.
# remote: Compressing objects: 100% (133/133), done.objects:  29% (39/133)
# remote: Total 352402 (delta 98), reused 137 (delta 74), pack-reused 352191
# Receiving objects: 100% (352402/352402), 1.08 GiB | 8.17 MiB/s, done.
# Resolving deltas: 100% (274245/274245), done.
# Updating files: 100% (8217/8217), done.

# %%
# %cd onnxruntime
# !git checkout rel-1.16.2
# !git pull
# Out:
# /Users/vadimmakarov/Documents/Work_home/submission/train/onnxruntime
# branch 'rel-1.16.2' set up to track 'origin/rel-1.16.2'.
# Switched to a new branch 'rel-1.16.2'
# Already up to date.

# %%
# %cd ..
# !python -m onnxruntime.tools.convert_onnx_models_to_ort model.onnx \
	--optimization_style Runtime  --target_platform amd64
# Out:
# /Users/vadimmakarov/Documents/Work_home/submission/train
# Converting models with optimization style 'Runtime' and level 'all'
# Converting optimized ONNX model /Users/vadimmakarov/Documents/Work_home/submission/train/model.onnx to ORT format model /Users/vadimmakarov/Documents/Work_home/submission/train/model.with_runtime_opt.ort
# 2023-11-20 18:06:49.599919 [W:onnxruntime:, inference_session.cc:1719 Initialize] Serializing optimized model with Graph Optimization level greater than ORT_ENABLE_EXTENDED and the NchwcTransformer enabled. The generated model may contain hardware specific optimizations, and should only be used in the same environment the model was optimized in.
# Converted 1/1 models successfully.
# Converting models again without runtime optimizations to generate a complete config file. These converted models are temporary and will be deleted.
# ...

# %%
# !xxd -i model.with_runtime_opt.ort > model_data.h

# %%
# !cp model_data.h ../src/

# %%
# !export PATH="/home/vadim/cmake-3.26.1-linux-x86_64/bin:$PATH"

# %%
# %cd onnxruntime
# Out:
# /Users/vadimmakarov/Documents/Work_home/submission/train/onnxruntime

# %%
# !./build.sh   --config=Release   --build_shared_lib   --minimal_build   --disable_ml_ops \
	--disable_exceptions --disable_rtti  \
	--include_ops_by_config ../model.required_operators.with_runtime_opt.config \
	--enable_reduced_operator_type_support   --skip_tests  --parallel
# Out:
# 2023-11-20 18:13:22,585 build [DEBUG] - Command line arguments:
#   --build_dir /Users/vadimmakarov/Documents/Work_home/submission/train/onnxruntime/build/MacOS --config=Release --build_shared_lib --minimal_build --disable_ml_ops --disable_exceptions --disable_rtti --include_ops_by_config ../model.required_operators.with_runtime_opt.config --enable_reduced_operator_type_support --skip_tests --parallel
# ...

# %%
# !cp ./build/Linux/Release/libonnxruntime.so.1.16.2 ../../src/onnxruntime-linux-x64-1.16.2/lib/

# %% [markdown]
# Now u should rebuild library
